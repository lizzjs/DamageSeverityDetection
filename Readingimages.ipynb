# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls "/content/drive/My Drive"
# Out:
#  2023-04-04_transaction_download.csv   data3a
# 'BDM_Lab07_DataProc_Spark (1).ipynb'  'Final__BDM_HW2_J_S (1).ipynb'
#  BDM_Lab07_DataProc_Spark.ipynb        Final__BDM_HW2_JS_chek.ipynb
# 'Colab Notebooks'		       Final__BDM_HW2_JS.ipynb
# 'Cuentas Nov 22.xlsx'

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
import os
from PIL import Image
from matplotlib import pyplot as plt

# %%
rooth = '/content/drive/MyDrive/data3a/training/01-minor'

fnames = os.listdir(rooth)

# %%
len(fnames)
# Out:
# 452

# %%
for i in range (10):
  print(fnames[i])
# Out:
# 0039.JPEG
# images (51).jpeg
# 0193.JPEG
# 0255.JPEG
# images (14).jpeg
# ef2b325bcc164d6a8e834a57448b9343_thb.jpg
# 980e7f8c0c61405ca31db96964a1f273_thb.jpg
# 0081.JPEG
# 0214.JPEG
# 0202.JPEG

# %%
fig, axs = plt.subplots(nrows=2, ncols=5, figsize = (10,10))
axs=axs.flatten()

for i in range (10):
  filepath=os.path.join(rooth,fnames[i])
  img = Image.open(filepath)
  axs[i].imshow(img)
  axs[i].axis('off')
  # axs[i].set_title(fnames[i])
plt.show()

# %%
import cv2
import os

# %%
img_path = os.path.join('', '0data3a1-minor', '0001.JPEG')

# %%
img_path
# Out:
# 'data3a/01-minor/0001.JPEG'

# %%
img = cv2.imread('/content/drive/MyDrive/data3a/training/01-minor/0001.JPEG')

# %%
img.shape
# Out:
# (217, 233, 3)

# %%
from matplotlib import pyplot as plt

# %%
# Show image
plt.imshow(img)

# %%
for i in range (10):
  filepath=os.path.join(rooth,fnames[i])
  # img = Image.open(filepath)
  img = cv2.imread(filepath)
  # axs[i].set_title(fnames[i])

# %%
img
# Out:
# array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [155, 146, 133],
#         [121, 112,  99],
#         [119, 110,  97]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [125, 119, 106],
#         [101,  93,  80],
#         [111, 103,  90]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [160, 158, 147],
#         [140, 136, 125],
#         [155, 151, 140]],
#
#        ...,
#
#        [[ 76,  78,  78],
#         [ 76,  78,  78],
#         [ 76,  78,  78],
#         ...,
#         [145, 154, 158],
#         [145, 154, 158],
#         [146, 155, 159]],
#
#        [[ 76,  78,  78],
#         [ 76,  78,  78],
#         [ 76,  78,  78],
#         ...,
#         [154, 163, 167],
#         [156, 165, 169],
#         [159, 168, 172]],
#
#        [[ 76,  78,  78],
#         [ 76,  78,  78],
#         [ 76,  78,  78],
# ...

# %%
import pandas as pd

# BASE_DIR = 'images/'
train_folder = '/content/drive/MyDrive/data3a/training/01-minor'
# train_annotation = BASE_DIR+'annotated_train_data/'

files_in_train = sorted(os.listdir(train_folder))
# files_in_annotated = sorted(os.listdir(train_annotation))

images=[i for i in files_in_train]

df = pd.DataFrame()
df['images']=[train_folder+str(x) for x in images]
# df['labels']=[train_annotation+str(x) for x in images]

df.to_csv('files_path.csv', header=None)

# %%
df['images']
# Out:
# 0      /content/drive/MyDrive/data3a/training/01-mino...
# 1      /content/drive/MyDrive/data3a/training/01-mino...
# 2      /content/drive/MyDrive/data3a/training/01-mino...
# 3      /content/drive/MyDrive/data3a/training/01-mino...
# 4      /content/drive/MyDrive/data3a/training/01-mino...
#                              ...
# 447    /content/drive/MyDrive/data3a/training/01-mino...
# 448    /content/drive/MyDrive/data3a/training/01-mino...
# 449    /content/drive/MyDrive/data3a/training/01-mino...
# 450    /content/drive/MyDrive/data3a/training/01-mino...
# 451    /content/drive/MyDrive/data3a/training/01-mino...
# Name: images, Length: 452, dtype: object

# %%
len(data)
# Out:
# 0

# %%
from PIL import Image
import numpy as np


for i in range (5):
  filepath=os.path.join(rooth,fnames[i])
  # img = Image.open(filepath)
  # img = cv2.imread(filepath)
# 1. Read image
  img = Image.open(filepath)
# 2. Convert image to NumPy array
  arr = np.asarray(img)
  print(arr.shape)
# (771, 771, 3)
# 3. Convert 3D array to 2D list of lists
  lst = []
  for row in arr:
      tmp = []
      for col in row:
          tmp.append(str(col))
      lst.append(tmp)
# 4. Save list of lists to CSV
  with open(f'my_file{i}.csv', 'w') as f:
      for row in lst:
          f.write(','.join(row) + '\n')
# Out:
# (236, 214, 3)
# (168, 300, 3)
# (132, 178, 3)
# (224, 225, 3)
# (100, 100, 3)
